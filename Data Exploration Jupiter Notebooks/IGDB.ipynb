# %%
# Import libraries and Dependencies to be used in the project
import pandas as pd
import numpy as np
import requests
import json
import os
from dotenv import load_dotenv

# %%
#get private environment varibles from .env file
load_dotenv()
client_id = os.environ['TWITCH_CLIENT_ID']
client_secret = os.environ['TWITCH_CLIENT_SECRET']

# %%
#Define the Twitch varibles for a request to the twitch API to get the access token

twitch_url = 'https://id.twitch.tv/oauth2/token'
params = {
    'client_id': client_id,
    'client_secret': client_secret,
    'grant_type': 'client_credentials'
}

# %%
#make request to twitch API to get access token and store it in a variable
twitch_request = requests.post(twitch_url, data=params)

# %%
#Print the response from the request from Twitch API
print(twitch_request.text)
# Out:
# {"access_token":"4dtsb5b4kdqq3mr8prkggvhm7myaqo","expires_in":5612742,"token_type":"bearer"}

# %%
# Print the response from the request from Twitch API in a more readable format using json
print(json.dumps(twitch_request.json(), indent=4))
# Out:
# {
#     "access_token": "4dtsb5b4kdqq3mr8prkggvhm7myaqo",
#     "expires_in": 5612742,
#     "token_type": "bearer"
# }

# %%
#Save the access token so it can be used in next IGDB API call
bearer_token = twitch_request.json()['access_token']

# %%
# Define the IGDB varibles for a request to the IGDB API to get the access token
IGDB_URL = 'https://api.igdb.com/v4/games'

# %%
#Function to make API request to IGDB
def make_api_request(base_url, df_name):   
   offset = 0
   all_results = []
   #loop through all the results, 500 at a time since that is the max limit
   while True:
      
      #make request to IGDB API
      IGDB_request = requests.post(base_url, headers={'Client-ID': client_id, 'Authorization': f'Bearer {bearer_token }'}, data=f'fields *; limit 500; offset {offset};')
      IGDB_data = IGDB_request.json()
      
      all_results.extend(IGDB_data)
      
      #if it pulls less than 500 results, then it has reached the end of the data, so break the loop
      if len(IGDB_data) < 500:
         break
      
      offset += len(IGDB_data)
   #Put the results into a pandas normalized dataframe
   df_name = pd.json_normalize(all_results)
   df_name.head()
   return df_name

# %%
#Make API request to IGDB to get the data for the video games
VG_DF = make_api_request(IGDB_URL, 'VG_DF')

# %%
# Print the column information for the dataframe
VG_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 275217 entries, 0 to 275216
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       275217 non-null  int64
#  1   age_ratings              61429 non-null   object
#  2   alternative_names        61439 non-null   object
#  3   category                 275217 non-null  int64
#  4   cover                    210651 non-null  float64
#  5   created_at               275217 non-null  int64
#  6   external_games           256379 non-null  object
#  7   first_release_date       176914 non-null  float64
#  8   game_modes               154059 non-null  object
#  9   genres                   224466 non-null  object
#  10  involved_companies       119938 non-null  object
#  11  keywords                 91131 non-null   object
#  12  name                     275217 non-null  object
#  13  platforms                188293 non-null  object
#  14  player_perspectives      92978 non-null   object
#  15  release_dates            187102 non-null  object
#  16  screenshots              200342 non-null  object
#  17  similar_games            225062 non-null  object
#  18  slug                     275217 non-null  object
#  19  storyline                23386 non-null   object
#  20  summary                  235463 non-null  object
#  21  tags                     225081 non-null  object
#  22  themes                   149928 non-null  object
#  23  updated_at               275217 non-null  int64
#  24  url                      275217 non-null  object
#  25  videos                   61517 non-null   object
#  26  websites                 250938 non-null  object
#  27  checksum                 275217 non-null  object
#  28  game_localizations       24939 non-null   object
#  29  collection               33265 non-null   float64
#  30  multiplayer_modes        12396 non-null   object
#  31  status                   17539 non-null   float64
#  32  language_supports        138737 non-null  object
#  33  collections              38085 non-null   object
#  34  hypes                    10208 non-null   float64
#  35  artworks                 109456 non-null  object
#  36  version_parent           6615 non-null    float64
#  37  version_title            6547 non-null    object
#  38  parent_game              35858 non-null   float64
#  39  bundles                  12859 non-null   object
#  40  franchises               21689 non-null   object
#  41  follows                  24560 non-null   float64
#  42  rating                   30169 non-null   float64
#  43  rating_count             30169 non-null   float64
#  44  total_rating             35441 non-null   float64
#  45  total_rating_count       35441 non-null   float64
#  46  game_engines             25339 non-null   object
#  47  aggregated_rating        15321 non-null   float64
#  48  aggregated_rating_count  15321 non-null   float64
#  49  ports                    3876 non-null    object
#  50  dlcs                     2965 non-null    object
#  51  remakes                  917 non-null     object
#  52  franchise                1511 non-null    float64
#  53  expansions               715 non-null     object
#  54  standalone_expansions    276 non-null     object
#  55  forks                    57 non-null      object
#  56  remasters                955 non-null     object
#  57  expanded_games           1299 non-null    object
# dtypes: float64(15), int64(4), object(39)
# memory usage: 121.8+ MB

# %%
# Print and list the column names for the dataframe
VG_DF.columns
# Out:
# Index(['id', 'age_ratings', 'alternative_names', 'category', 'cover',
#        'created_at', 'external_games', 'first_release_date', 'game_modes',
#        'genres', 'involved_companies', 'keywords', 'name', 'platforms',
#        'player_perspectives', 'release_dates', 'screenshots', 'similar_games',
#        'slug', 'storyline', 'summary', 'tags', 'themes', 'updated_at', 'url',
#        'videos', 'websites', 'checksum', 'game_localizations', 'collection',
#        'multiplayer_modes', 'status', 'language_supports', 'collections',
#        'hypes', 'artworks', 'version_parent', 'version_title', 'parent_game',
#        'bundles', 'franchises', 'follows', 'rating', 'rating_count',
#        'total_rating', 'total_rating_count', 'game_engines',
#        'aggregated_rating', 'aggregated_rating_count', 'ports', 'dlcs',
#        'remakes', 'franchise', 'expansions', 'standalone_expansions', 'forks',
#        'remasters', 'expanded_games'],
#       dtype='object')

# %%
#Testing to see if the data was pulled correctly
BG3 = VG_DF.loc[VG_DF['name'] == "Baldur's Gate 3"]
BG3
# Out:
#            id                                       age_ratings  \
# 88047  119171  [148088, 161963, 162025, 162026, 162027, 162028]
#
#                           alternative_names  category     cover  created_at  \
# 88047  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
#
#                                           external_games  first_release_date  \
# 88047  [1725312, 1775824, 1914473, 2070558, 2678929, ...        1.601942e+09
#
#          game_modes                genres  ... aggregated_rating_count ports  \
# 88047  [1, 2, 3, 4]  [12, 15, 16, 24, 31]  ...                    17.0   NaN
#
#       dlcs remakes franchise expansions standalone_expansions forks remasters  \
# 88047  NaN     NaN       NaN        NaN                   NaN   NaN       NaN
#
#       expanded_games
# 88047            NaN
#
# [1 rows x 58 columns]

# %%
#Testing to make sure the .datetime works on this data (this took forever)
BG3['first_release_date'] = pd.to_datetime(BG3['first_release_date'], infer_datetime_format=True, unit='s')
# Out:
# C:\Users\Keegan\AppData\Local\Temp\ipykernel_3256\3513838881.py:2: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   BG3['first_release_date'] = pd.to_datetime(BG3['first_release_date'], infer_datetime_format=True, unit='s')
# C:\Users\Keegan\AppData\Local\Temp\ipykernel_3256\3513838881.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BG3['first_release_date'] = pd.to_datetime(BG3['first_release_date'], infer_datetime_format=True, unit='s')

# %%
# List the dataframe for Baldurs Gate 3
BG3
# Out:
#            id                                       age_ratings  \
# 88047  119171  [148088, 161963, 162025, 162026, 162027, 162028]
#
#                           alternative_names  category     cover  created_at  \
# 88047  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
#
#                                           external_games first_release_date  \
# 88047  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
#
#          game_modes                genres  ... aggregated_rating_count ports  \
# 88047  [1, 2, 3, 4]  [12, 15, 16, 24, 31]  ...                    17.0   NaN
#
#       dlcs remakes franchise expansions standalone_expansions forks remasters  \
# 88047  NaN     NaN       NaN        NaN                   NaN   NaN       NaN
#
#       expanded_games
# 88047            NaN
#
# [1 rows x 58 columns]

# %%
#make a copy of the dataframe so that the original data is not altered
copy_df = VG_DF.copy()

# %%
#drop any rows that have a NaN value in the 'first_release_date' column
copy_df = copy_df.dropna(subset=['first_release_date'], how='any')

copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 176914 entries, 0 to 275216
# Data columns (total 58 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       176914 non-null  int64
#  1   age_ratings              54923 non-null   object
#  2   alternative_names        51198 non-null   object
#  3   category                 176914 non-null  int64
#  4   cover                    157144 non-null  float64
#  5   created_at               176914 non-null  int64
#  6   external_games           160793 non-null  object
#  7   first_release_date       176914 non-null  float64
#  8   game_modes               128009 non-null  object
#  9   genres                   158693 non-null  object
#  10  involved_companies       109941 non-null  object
#  11  keywords                 77192 non-null   object
#  12  name                     176914 non-null  object
#  13  platforms                176914 non-null  object
#  14  player_perspectives      84983 non-null   object
#  15  release_dates            176914 non-null  object
#  16  screenshots              140528 non-null  object
#  17  similar_games            159063 non-null  object
#  18  slug                     176914 non-null  object
#  19  storyline                21216 non-null   object
#  20  summary                  164578 non-null  object
#  21  tags                     159074 non-null  object
#  22  themes                   111816 non-null  object
#  23  updated_at               176914 non-null  int64
#  24  url                      176914 non-null  object
#  25  videos                   53850 non-null   object
#  26  websites                 159095 non-null  object
#  27  checksum                 176914 non-null  object
#  28  game_localizations       22496 non-null   object
#  29  collection               30071 non-null   float64
#  30  multiplayer_modes        11067 non-null   object
#  31  status                   12719 non-null   float64
#  32  language_supports        93955 non-null   object
#  33  collections              34520 non-null   object
#  34  hypes                    7960 non-null    float64
#  35  artworks                 68441 non-null   object
#  36  version_parent           4795 non-null    float64
#  37  version_title            4735 non-null    object
#  38  parent_game              25488 non-null   float64
#  39  bundles                  11851 non-null   object
#  40  franchises               19965 non-null   object
#  41  follows                  23343 non-null   float64
#  42  rating                   29019 non-null   float64
#  43  rating_count             29019 non-null   float64
#  44  total_rating             33888 non-null   float64
#  45  total_rating_count       33888 non-null   float64
#  46  game_engines             22259 non-null   object
#  47  aggregated_rating        14911 non-null   float64
#  48  aggregated_rating_count  14911 non-null   float64
#  49  ports                    3791 non-null    object
#  50  dlcs                     2809 non-null    object
#  51  remakes                  899 non-null     object
#  52  franchise                1508 non-null    float64
#  53  expansions               706 non-null     object
#  54  standalone_expansions    267 non-null     object
#  55  forks                    54 non-null      object
#  56  remasters                931 non-null     object
#  57  expanded_games           1260 non-null    object
# dtypes: float64(15), int64(4), object(39)
# memory usage: 79.6+ MB

# %%
#convert the 'first_release_date' column to a datetime object
copy_df['first_release_date'] = pd.to_datetime(copy_df['first_release_date'], errors = 'coerce',  unit='s')

# %%
# Print and generate a copy of the dataframe
copy_df.head()
# Out:
#         id                                       age_ratings  \
# 0   131913                                          [101730]
# 1    88308                                               NaN
# 2    63308                                           [14739]
# 9   231577  [114607, 114609, 126972, 126973, 126974, 127011]
# 10  119025                                               NaN
#
#         alternative_names  category     cover  created_at  \
# 0   [40085, 40086, 40087]         0  267633.0  1584788069
# 1                     NaN         0   64849.0  1519237439
# 2                     NaN         0   78658.0  1505087910
# 9                     NaN         0  280467.0  1673878007
# 10                    NaN         0       NaN  1558701524
#
#                                    external_games first_release_date  \
# 0                                       [1977891]         2016-09-21
# 1                               [243459, 1960113]         2016-11-09
# 2                        [12596, 118080, 1185144]         2013-07-03
# 9   [2639959, 2677882, 2677897, 2677919, 2678595]         2023-02-23
# 10                             [1723803, 1957721]         2019-06-08
#
#    game_modes genres  ... aggregated_rating_count ports dlcs remakes  \
# 0         [1]   [34]  ...                     NaN   NaN  NaN     NaN
# 1         NaN    NaN  ...                     NaN   NaN  NaN     NaN
# 2      [2, 3]    [5]  ...                     NaN   NaN  NaN     NaN
# 9      [1, 2]   [15]  ...                     NaN   NaN  NaN     NaN
# 10        [1]   [13]  ...                     NaN   NaN  NaN     NaN
#
#    franchise expansions standalone_expansions forks remasters expanded_games
# 0        NaN        NaN                   NaN   NaN       NaN            NaN
# 1        NaN        NaN                   NaN   NaN       NaN            NaN
# 2        NaN        NaN                   NaN   NaN       NaN            NaN
# 9        NaN        NaN                   NaN   NaN       NaN            NaN
# 10       NaN        NaN                   NaN   NaN       NaN            NaN
#
# [5 rows x 58 columns]

# %%
# Define a string variable for the IGDB API request to get the release dates
release_dates_url = 'https://api.igdb.com/v4/release_dates'

# %%
#make API request to IGDB to get the data for the release dates
RD_DF = make_api_request(release_dates_url, 'RD_DF')
RD_DF.head()
# Out:
#        id  category  created_at          date    game         human    m  \
# 0     298         2  1301923501  7.258464e+08     110          1993  1.0
# 1  165447         0  1550867412  1.561421e+09  115477  Jun 25, 2019  6.0
# 2  143501         0  1517637179  1.210118e+09   37605  May 07, 2008  5.0
# 3  240506         0  1619125310  1.622160e+09   56914  May 28, 2021  5.0
# 4  310513         0  1631498490  6.318432e+08   48393  Jan 09, 1990  1.0
#
#    platform  region  updated_at       y                              checksum  \
# 0         6       8  1339423931  1993.0  09293025-b7e0-1565-8848-532914a16081
# 1         6       8  1550867489  2019.0  79b1fc63-2f73-5351-c0f2-6b4fe6cb33fb
# 2         5       5  1517864621  2008.0  5114450a-b7e1-c105-a3b9-08ad7b2e4321
# 3        48       2  1619163937  2021.0  d4c4a16e-f78d-ae3d-9922-04b3b5a7cdad
# 4        99       5  1631499375  1990.0  530d65c3-cbbe-9a9a-eea0-a999c0e5c61f
#
#    status
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#convert the 'date' column to a datetime object
RD_DF['date'] = pd.to_datetime(RD_DF['date'], errors = 'coerce', unit='s')
RD_DF.head()
# Out:
#        id  category  created_at       date    game         human    m  \
# 0     298         2  1301923501 1993-01-01     110          1993  1.0
# 1  165447         0  1550867412 2019-06-25  115477  Jun 25, 2019  6.0
# 2  143501         0  1517637179 2008-05-07   37605  May 07, 2008  5.0
# 3  240506         0  1619125310 2021-05-28   56914  May 28, 2021  5.0
# 4  310513         0  1631498490 1990-01-09   48393  Jan 09, 1990  1.0
#
#    platform  region  updated_at       y                              checksum  \
# 0         6       8  1339423931  1993.0  09293025-b7e0-1565-8848-532914a16081
# 1         6       8  1550867489  2019.0  79b1fc63-2f73-5351-c0f2-6b4fe6cb33fb
# 2         5       5  1517864621  2008.0  5114450a-b7e1-c105-a3b9-08ad7b2e4321
# 3        48       2  1619163937  2021.0  d4c4a16e-f78d-ae3d-9922-04b3b5a7cdad
# 4        99       5  1631499375  1990.0  530d65c3-cbbe-9a9a-eea0-a999c0e5c61f
#
#    status
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
#remove unnecessary columns
dates_ids = RD_DF[['id', 'date']]
dates_ids.head()
# Out:
#        id       date
# 0     298 1993-01-01
# 1  165447 2019-06-25
# 2  143501 2008-05-07
# 3  240506 2021-05-28
# 4  310513 1990-01-09

# %%
#rename columns
dates_ids = dates_ids.rename(columns={'id': 'release_date_id', 'date':'release_date_data' })
dates_ids.head()
# Out:
#    release_date_id release_date_data
# 0              298        1993-01-01
# 1           165447        2019-06-25
# 2           143501        2008-05-07
# 3           240506        2021-05-28
# 4           310513        1990-01-09

# %%
#merge the two dataframes, 'copy_df' and 'dates_ids', on the 'release_dates' column, which is a list of release date ids
merged_df = copy_df.explode('release_dates').merge(dates_ids, left_on='release_dates', right_on='release_date_id', how='left')
merged_df[['name', 'first_release_date', 'release_date_data', 'release_dates', 'release_date_id']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 348221 entries, 0 to 348220
# Data columns (total 5 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   name                348221 non-null  object
#  1   first_release_date  348220 non-null  datetime64[ns]
#  2   release_date_data   343995 non-null  datetime64[ns]
#  3   release_dates       348221 non-null  object
#  4   release_date_id     348221 non-null  int64
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 13.3+ MB

# %%
#drop the 'release_dates' column
merged_df['release_dates'] = merged_df['release_date_data']
merged_df = merged_df.drop(columns=['release_date_data', 'release_date_id'])

# %%
merged_df[['name', 'release_dates']].head()
# Out:
#                                name release_dates
# 0            Maji Kyun! Renaissance    2016-09-21
# 1   Hey Duggee: The Big Outdoor App    2016-11-09
# 2                   Soldier Front 2    2013-07-03
# 3  Blood Bowl 3: Black Orcs Edition    2023-02-23
# 4  Blood Bowl 3: Black Orcs Edition    2023-02-23

# %%
# Keep all columns for now
all_columns = ['id', 'age_ratings', 'alternative_names', 'category', 'cover',
       'created_at', 'external_games', 'first_release_date', 'game_modes',
       'genres', 'involved_companies', 'keywords', 'name', 'platforms',
       'player_perspectives', 'release_dates', 'screenshots', 'similar_games',
       'slug', 'storyline', 'summary', 'tags', 'themes', 'updated_at', 'url',
       'videos', 'websites', 'checksum', 'game_localizations', 'collection',
       'multiplayer_modes', 'status', 'language_supports', 'collections',
       'hypes', 'artworks', 'version_parent', 'version_title', 'parent_game',
       'bundles', 'franchises', 'follows', 'rating', 'rating_count',
       'total_rating', 'total_rating_count', 'game_engines',
       'aggregated_rating', 'aggregated_rating_count', 'ports', 'dlcs',
       'remakes', 'franchise', 'expansions', 'standalone_expansions', 'forks',
       'remasters', 'expanded_games']

# %%
#combine rows on the name so that the 'release dates' is a list
# Group by 'name' and aggregate 'first_release_date' and 'release_dates' into lists
merged_df = merged_df[all_columns]
merged_df = merged_df.groupby('name', as_index=False).agg({
    'id': 'first',
    'age_ratings': 'first',
    'alternative_names': 'first',
    'category': 'first',
    'cover': 'first',
    'created_at': 'first',
    'external_games': 'first',
    'first_release_date': 'first',
    'game_modes': 'first',
    'genres': 'first',
    'involved_companies': 'first',
    'keywords': 'first',
    'platforms': 'first',
    'player_perspectives': 'first',
    'release_dates': list,
    'screenshots': 'first',
    'similar_games': 'first',
    'slug': 'first',
    'storyline': 'first',
    'summary': 'first',
    'tags': 'first',
    'themes': 'first',
    'updated_at': 'first',
    'url': 'first',
    'videos': 'first',
    'websites': 'first',
    'checksum': 'first',
    'game_localizations': 'first',
    'collection': 'first',
    'multiplayer_modes': 'first',
    'status': 'first',
    'language_supports': 'first',
    'collections': 'first',
    'hypes': 'first',
    'artworks': 'first',
    'version_parent': 'first',
    'version_title': 'first',
    'parent_game': 'first',
    'bundles': 'first',
    'franchises': 'first',
    'follows': 'first',
    'rating': 'first',
    'rating_count': 'first',
    'total_rating': 'first',
    'total_rating_count': 'first',
    'game_engines': 'first',
    'aggregated_rating': 'first',
    'aggregated_rating_count': 'first',
    'ports': 'first',
    'dlcs': 'first',
    'remakes': 'first',
    'franchise': 'first',
    'expansions': 'first',
    'standalone_expansions': 'first',
    'forks': 'first',
    'remasters': 'first',
    'expanded_games': 'first'
})

# %%
#Testing to see if the data was merged correctly It is working now
BG3_2 = merged_df.loc[merged_df['name'] == "Baldur's Gate 3"]
BG3_2[['release_dates', 'first_release_date', 'name']].head()
# Out:
#                                            release_dates first_release_date  \
# 13628  [2023-09-06 00:00:00, 2023-08-03 00:00:00, 202...         2020-10-06
#
#                   name
# 13628  Baldur's Gate 3

# %%
BG3_2.head()
# Out:
#                   name      id  \
# 13628  Baldur's Gate 3  119171
#
#                                             age_ratings  \
# 13628  [148088, 161963, 162025, 162026, 162027, 162028]
#
#                           alternative_names  category     cover  created_at  \
# 13628  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
#
#                                           external_games first_release_date  \
# 13628  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
#
#          game_modes  ... aggregated_rating_count ports  dlcs remakes  \
# 13628  [1, 2, 3, 4]  ...                    17.0  None  None    None
#
#       franchise expansions standalone_expansions forks remasters  \
# 13628       NaN       None                  None  None      None
#
#       expanded_games
# 13628           None
#
# [1 rows x 58 columns]

# %%
genre_url = 'https://api.igdb.com/v4/genres'
genre_df = make_api_request(genre_url, 'genre_df')

# %%
genre_df.head()
# Out:
#    id  created_at             name             slug  updated_at  \
# 0   2  1297639288  Point-and-click  point-and-click  1323382086
# 1   4  1297639288         Fighting         fighting  1323289215
# 2   5  1297639288          Shooter          shooter  1323289215
# 3   7  1297639288            Music            music  1323289215
# 4   8  1297639288         Platform         platform  1323289215
#
#                                            url  \
# 0  https://www.igdb.com/genres/point-and-click
# 1         https://www.igdb.com/genres/fighting
# 2          https://www.igdb.com/genres/shooter
# 3            https://www.igdb.com/genres/music
# 4         https://www.igdb.com/genres/platform
#
#                                checksum
# 0  47a23b47-ad82-9d36-517a-41b23073a58f
# 1  f64573d0-92ea-1298-1f2e-5b6a4b309eb5
# 2  d085fd73-9514-e857-cb35-7cd5b6e952b1
# 3  bb04b3e2-66b3-1ff4-bef6-464346f4ffd9
# 4  ff5b1711-9f9a-fec6-f391-f3b00a9682c1

# %%
genre_df.drop(columns=['slug','updated_at','url','checksum','created_at'], inplace=True)
genre_df.rename(columns={'id':'genre_id', 'name':'genre_name'}, inplace=True)
genre_df
# Out:
#     genre_id                  genre_name
# 0          2             Point-and-click
# 1          4                    Fighting
# 2          5                     Shooter
# 3          7                       Music
# 4          8                    Platform
# 5          9                      Puzzle
# 6         10                      Racing
# 7         11    Real Time Strategy (RTS)
# 8         12          Role-playing (RPG)
# 9         13                   Simulator
# 10        14                       Sport
# 11        15                    Strategy
# 12        16   Turn-based strategy (TBS)
# 13        24                    Tactical
# 14        25  Hack and slash/Beat 'em up
# 15        26                 Quiz/Trivia
# 16        30                     Pinball
# 17        31                   Adventure
# 18        32                       Indie
# 19        33                      Arcade
# 20        34                Visual Novel
# 21        35           Card & Board Game
# 22        36                        MOBA

# %%
# Merge genre_df with merged_df to replace genre_id with genre_name
genre_merged_df = merged_df.explode('genres').merge(genre_df, left_on='genres', right_on='genre_id', how='left')

# Drop the old 'genres' column and rename the 'genre_name' column
genre_merged_df.drop(columns=['genres'], inplace=True)
genre_merged_df.rename(columns={'genre_name': 'genres'}, inplace=True)

genre_merged_df[['name', 'genres']].head()
# Out:
#                       name           genres
# 0                        !  Point-and-click
# 1                        !           Puzzle
# 2                        !        Adventure
# 3  !Dead Pixels Adventure!        Adventure
# 4  !Dead Pixels Adventure!            Indie

# %%
BG3_4 = genre_merged_df.loc[genre_merged_df['name']=="Baldur's Gate 3"]
BG3_4
# Out:
#                   name      id  \
# 25422  Baldur's Gate 3  119171
# 25423  Baldur's Gate 3  119171
# 25424  Baldur's Gate 3  119171
# 25425  Baldur's Gate 3  119171
# 25426  Baldur's Gate 3  119171
#
#                                             age_ratings  \
# 25422  [148088, 161963, 162025, 162026, 162027, 162028]
# 25423  [148088, 161963, 162025, 162026, 162027, 162028]
# 25424  [148088, 161963, 162025, 162026, 162027, 162028]
# 25425  [148088, 161963, 162025, 162026, 162027, 162028]
# 25426  [148088, 161963, 162025, 162026, 162027, 162028]
#
#                           alternative_names  category     cover  created_at  \
# 25422  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
# 25423  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
# 25424  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
# 25425  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
# 25426  [50217, 78595, 78596, 78597, 139162]         0  289025.0  1559228938
#
#                                           external_games first_release_date  \
# 25422  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
# 25423  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
# 25424  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
# 25425  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
# 25426  [1725312, 1775824, 1914473, 2070558, 2678929, ...         2020-10-06
#
#          game_modes  ...  dlcs remakes franchise expansions  \
# 25422  [1, 2, 3, 4]  ...  None    None       NaN       None
# 25423  [1, 2, 3, 4]  ...  None    None       NaN       None
# 25424  [1, 2, 3, 4]  ...  None    None       NaN       None
# 25425  [1, 2, 3, 4]  ...  None    None       NaN       None
# 25426  [1, 2, 3, 4]  ...  None    None       NaN       None
#
#       standalone_expansions forks remasters expanded_games genre_id  \
# 25422                  None  None      None           None     12.0
# 25423                  None  None      None           None     15.0
# 25424                  None  None      None           None     16.0
# 25425                  None  None      None           None     24.0
# 25426                  None  None      None           None     31.0
#
#                           genres
# 25422         Role-playing (RPG)
# 25423                   Strategy
# 25424  Turn-based strategy (TBS)
# 25425                   Tactical
# 25426                  Adventure
#
# [5 rows x 59 columns]

# %%
#combine rows on the name so that the 'genres' is a list
# Group by 'name' and aggregate 'genres' into lists

genre_merged_df = genre_merged_df.groupby('name', as_index=False).agg({
    'id': 'first',
    'age_ratings': 'first',
    'alternative_names': 'first',
    'category': 'first',
    'cover': 'first',
    'created_at': 'first',
    'external_games': 'first',
    'first_release_date': 'first',
    'game_modes': 'first',
    'genres': list,
    'involved_companies': 'first',
    'keywords': 'first',
    'platforms': 'first',
    'player_perspectives': 'first',
    'release_dates': list,
    'screenshots': 'first',
    'similar_games': 'first',
    'slug': 'first',
    'storyline': 'first',
    'summary': 'first',
    'tags': 'first',
    'themes': 'first',
    'updated_at': 'first',
    'url': 'first',
    'videos': 'first',
    'websites': 'first',
    'checksum': 'first',
    'game_localizations': 'first',
    'collection': 'first',
    'multiplayer_modes': 'first',
    'status': 'first',
    'language_supports': 'first',
    'collections': 'first',
    'hypes': 'first',
    'artworks': 'first',
    'version_parent': 'first',
    'version_title': 'first',
    'parent_game': 'first',
    'bundles': 'first',
    'franchises': 'first',
    'follows': 'first',
    'rating': 'first',
    'rating_count': 'first',
    'total_rating': 'first',
    'total_rating_count': 'first',
    'game_engines': 'first',
    'aggregated_rating': 'first',
    'aggregated_rating_count': 'first',
    'ports': 'first',
    'dlcs': 'first',
    'remakes': 'first',
    'franchise': 'first',
    'expansions': 'first',
    'standalone_expansions': 'first',
    'forks': 'first',
    'remasters': 'first',
    'expanded_games': 'first'
})

# %%
BG3_5 = genre_merged_df.loc[genre_merged_df['name']=="Baldur's Gate 3"]
BG3_5[['name','release_dates','genres']].head()
# Out:
#                   name                                      release_dates  \
# 13628  Baldur's Gate 3  [[2023-09-06 00:00:00, 2023-08-03 00:00:00, 20...
#
#                                                   genres
# 13628  [Role-playing (RPG), Strategy, Turn-based stra...

# %%
#output the data to a csv file
genre_merged_df.to_csv('../Uncleaned Data/uncleaned_video_games.csv', index=False)

# %%
#read the data back in to make sure it was saved correctly
Video_games_df = pd.read_csv('../Uncleaned Data/uncleaned_video_games.csv')
Video_games_df.columns
# Out:
# Index(['name', 'id', 'age_ratings', 'alternative_names', 'category', 'cover',
#        'created_at', 'external_games', 'first_release_date', 'game_modes',
#        'genres', 'involved_companies', 'keywords', 'platforms',
#        'player_perspectives', 'release_dates', 'screenshots', 'similar_games',
#        'slug', 'storyline', 'summary', 'tags', 'themes', 'updated_at', 'url',
#        'videos', 'websites', 'checksum', 'game_localizations', 'collection',
#        'multiplayer_modes', 'status', 'language_supports', 'collections',
#        'hypes', 'artworks', 'version_parent', 'version_title', 'parent_game',
#        'bundles', 'franchises', 'follows', 'rating', 'rating_count',
#        'total_rating', 'total_rating_count', 'game_engines',
#        'aggregated_rating', 'aggregated_rating_count', 'ports', 'dlcs',
#        'remakes', 'franchise', 'expansions', 'standalone_expansions', 'forks',
#        'remasters', 'expanded_games'],
#       dtype='object')

# %%
#drop unnecessary columns from the dataframe that are not needed for the analysis
cols_to_delete = ['age_ratings', 'alternative_names','cover','created_at', 'external_games','game_modes','involved_companies', 'keywords','platforms',
       'player_perspectives','screenshots', 'similar_games',
       'slug', 'storyline', 'summary', 'tags', 'themes', 'updated_at', 'url',
       'videos', 'websites', 'checksum', 'game_localizations', 'collection',
       'multiplayer_modes', 'status', 'language_supports', 'collections',
       'hypes', 'artworks', 'version_parent', 'version_title', 'parent_game',
       'bundles', 'franchises', 'follows','game_engines','ports', 'dlcs',
       'remakes', 'franchise', 'expansions', 'standalone_expansions', 'forks',
       'remasters', 'expanded_games']
cleaned_df = Video_games_df.drop(columns=cols_to_delete)
cleaned_df.head()
# Out:
#                              name      id  category first_release_date  \
# 0                               !  165498         0         2009-12-31
# 1         !Dead Pixels Adventure!  103013         0         2018-06-12
# 2                        !Pattern  225575         0         2022-11-05
# 3         "Draw a card" Simulator  168659         0         2020-08-26
# 4  "Gamer"+ Crossroad of Sympathy  186065         0         2021-01-21
#
#                                        genres  \
# 0  ['Point-and-click', 'Puzzle', 'Adventure']
# 1                      ['Adventure', 'Indie']
# 2                         ['Puzzle', 'Indie']
# 3                               ['Simulator']
# 4                   ['Indie', 'Visual Novel']
#
#                                        release_dates  rating  rating_count  \
# 0  [[Timestamp('2009-12-31 00:00:00')], [Timestam...     NaN           NaN
# 1  [[Timestamp('2018-06-12 00:00:00')], [Timestam...     NaN           NaN
# 2  [[Timestamp('2022-11-05 00:00:00')], [Timestam...     NaN           NaN
# 3               [[Timestamp('2020-08-26 00:00:00')]]     NaN           NaN
# 4  [[Timestamp('2021-01-21 00:00:00'), Timestamp(...     NaN           NaN
#
#    total_rating  total_rating_count  aggregated_rating  \
# 0           NaN                 NaN                NaN
# 1           NaN                 NaN                NaN
# 2           NaN                 NaN                NaN
# 3           NaN                 NaN                NaN
# 4           NaN                 NaN                NaN
#
#    aggregated_rating_count
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN

# %%
# Print the column information for the dataframe
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168437 entries, 0 to 168436
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   name                     168436 non-null  object
#  1   id                       168437 non-null  int64
#  2   category                 168437 non-null  int64
#  3   first_release_date       168436 non-null  object
#  4   genres                   168437 non-null  object
#  5   release_dates            168437 non-null  object
#  6   rating                   28526 non-null   float64
#  7   rating_count             28526 non-null   float64
#  8   total_rating             33160 non-null   float64
#  9   total_rating_count       33160 non-null   float64
#  10  aggregated_rating        14603 non-null   float64
#  11  aggregated_rating_count  14603 non-null   float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 15.4+ MB

# %%
#drop null values from rating column
cleaned_df = cleaned_df.dropna(subset=['rating'])

cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28526 entries, 12 to 168393
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   name                     28526 non-null  object
#  1   id                       28526 non-null  int64
#  2   category                 28526 non-null  int64
#  3   first_release_date       28526 non-null  object
#  4   genres                   28526 non-null  object
#  5   release_dates            28526 non-null  object
#  6   rating                   28526 non-null  float64
#  7   rating_count             28526 non-null  float64
#  8   total_rating             28526 non-null  float64
#  9   total_rating_count       28526 non-null  float64
#  10  aggregated_rating        9969 non-null   float64
#  11  aggregated_rating_count  9969 non-null   float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 2.8+ MB

# %%
# Print the column information for the dataframe
cleaned_df.head(50)
# Out:
#                                                   name      id  category  \
# 12                                          "Two Draw"   74340         0
# 23                                            #Archery   32298         0
# 25                                #Breakforcist Battle   96199        11
# 32                                              #IDARB    9888         0
# 33                                     #Killallzombies   26369         0
# 39                                       #SelfieTennis   34683         0
# 42                                           #WarGames   76767         0
# 45                                             $1 Ride   31922         0
# 62                                 'n Verlore Verstand   19055         0
# 85                                            .Detuned    7724         0
# 90                                               .Flow   24958         0
# 92                             .Hack//G.U. Last Recode   37134         3
# 93                         .Hack//G.U. Vol. 1: Rebirth   11987         0
# 95                       .Hack//G.U. Vol. 2: Reminisce   11988         0
# 100                                   .Hack//Infection   11807         0
# 101                                    .Hack//Mutation   11808         0
# 102                                    .Hack//Outbreak   11809         0
# 103                                  .Hack//Quarantine   11810         0
# 105                       .T.E.S.T: Expected Behaviour   86524         0
# 135                                        007 Legends    1649         0
# 139                                         007 Racing    1642         0
# 146                                              03.04  113188         0
# 155                                          0rbitalis    9583         0
# 160                                            0°N 0°W   55486         0
# 177                      1 Moment of Time: Silentville   32199         0
# 180                                1 Screen Platformer   97902         0
# 190                                          1 vs. 100   74406         0
# 196                                         1-2-Switch   26762         0
# 206  1... 2... 3... Kick It!: Drop That Beat Like a...   15938         0
# 231                                 10 Miles to Safety  122809         0
# 232                                10 Minute Barbarian   34776         0
# 240                         10 Pin Shuffle Pro Bowling   88351         0
# 243                                    10 Second Ninja    9848         0
# 244                                  10 Second Ninja X   18686         0
# 245                              10 Second Run Returns   83868         0
# 255                                     10 Years After   36024         0
# 283                                      10-Yard Fight  229983        11
# 284                         10-in-1: Arcade Collection   84612         0
# 296                        100 Classic Book Collection   47939         0
# 310                                           100 Euro  115826         0
# 325                                    100 Hidden Dogs  187215         0
# 328                                   100 Hidden Frogs  186155         0
# 357                                      100 Pics Quiz   70890         0
# 381                                  100% Orange Juice   11426         0
# 424                                          1000 Amps    6281         0
# 431                                1000 Days to Escape  120028         0
# 433                         1000 Heads Among the Trees   34360         0
# 450                                           10000000    9705         0
# 496                    1001 Jigsaw: Earth Chronicles 3   90040         0
# 512                                        1001 Spikes    8617        10
#
#     first_release_date                                             genres  \
# 12          2017-10-19                              ['Strategy', 'Indie']
# 23          2017-03-30                                 ['Sport', 'Indie']
# 25          2018-04-12                      ['Puzzle', 'Indie', 'Arcade']
# 32          2015-01-30                     ['Platform', 'Sport', 'Indie']
# 33          2014-10-28                     ['Shooter', 'Indie', 'Arcade']
# 39          2016-04-01                                 ['Sport', 'Indie']
# 42          2018-03-14                ['Simulator', 'Adventure', 'Indie']
# 45          2016-07-28                               ['Shooter', 'Indie']
# 62          2016-04-05       ['Platform', 'Puzzle', 'Adventure', 'Indie']
# 85          2009-09-17                                 ['Music', 'Indie']
# 90          2009-02-15                             ['Adventure', 'Indie']
# 92          2017-11-03                ['Role-playing (RPG)', 'Adventure']
# 93          2006-05-18                             ['Role-playing (RPG)']
# 95          2006-09-28                             ['Role-playing (RPG)']
# 100         2002-06-20  ['Role-playing (RPG)', "Hack and slash/Beat 'e...
# 101         2002-09-09  ['Role-playing (RPG)', "Hack and slash/Beat 'e...
# 102         2002-12-12  ['Role-playing (RPG)', "Hack and slash/Beat 'e...
# 103         2003-04-10  ['Role-playing (RPG)', "Hack and slash/Beat 'e...
# 105         2018-05-03      ['Puzzle', 'Simulator', 'Adventure', 'Indie']
# 135         2012-10-16                                        ['Shooter']
# 139         2000-11-20                                         ['Racing']
# 146         2019-01-01                             ['Adventure', 'Indie']
# 155         2014-04-16                   ['Puzzle', 'Simulator', 'Indie']
# 160         2018-03-02                             ['Adventure', 'Indie']
# 177         2012-06-16  ['Point-and-click', 'Puzzle', 'Adventure', 'In...
# 180         2019-03-07                 ['Platform', 'Adventure', 'Indie']
# 190         2009-11-19                                    ['Quiz/Trivia']
# 196         2017-03-03                                         ['Arcade']
# 206         2011-04-01                                 ['Music', 'Indie']
# 231         2019-10-21                  ['Fighting', 'Strategy', 'Indie']
# 232         2016-01-27                              ['Strategy', 'Indie']
# 240         2009-05-25                                ['Sport', 'Arcade']
# 243         2014-03-05                              ['Platform', 'Indie']
# 244         2016-07-19  ['Fighting', 'Platform', 'Puzzle', 'Indie', 'A...
# 245         2017-12-21                             ['Platform', 'Racing']
# 255         2015-01-30  ['Shooter', 'Role-playing (RPG)', 'Adventure',...
# 283         1985-08-30                                ['Sport', 'Arcade']
# 284         2013-08-01                                         ['Arcade']
# 296         2008-12-26                                              [nan]
# 310         2019-03-18                                              [nan]
# 325         2021-10-15          ['Point-and-click', 'Adventure', 'Indie']
# 328         2021-11-15          ['Point-and-click', 'Adventure', 'Indie']
# 357         2013-07-03                                         ['Puzzle']
# 381         2009-08-15  ['Strategy', 'Turn-based strategy (TBS)', 'Ind...
# 424         2012-02-22       ['Platform', 'Puzzle', 'Adventure', 'Indie']
# 431         2019-07-25                   ['Simulator', 'Indie', 'Arcade']
# 433         2015-12-11                                          ['Indie']
# 450         2012-02-17  ['Puzzle', 'Role-playing (RPG)', 'Simulator', ...
# 496         2015-11-30                                         ['Puzzle']
# 512         2014-06-03       ['Platform', 'Adventure', 'Indie', 'Arcade']
#
#                                          release_dates     rating  \
# 12   [[Timestamp('2017-10-19 00:00:00')], [Timestam...  70.000000
# 23   [[Timestamp('2017-03-30 00:00:00')], [Timestam...  50.000000
# 25   [[Timestamp('2018-04-12 00:00:00'), Timestamp(...  63.000000
# 32   [[Timestamp('2015-01-30 00:00:00'), Timestamp(...  77.953028
# 33   [[Timestamp('2014-10-28 00:00:00'), Timestamp(...  70.000000
# 39   [[Timestamp('2016-04-01 00:00:00'), NaT], [Tim...  60.000000
# 42   [[Timestamp('2018-12-31 00:00:00'), Timestamp(...  50.000000
# 45   [[Timestamp('2016-07-28 00:00:00')], [Timestam...  50.000000
# 62   [[Timestamp('2016-04-05 00:00:00'), Timestamp(...  70.000000
# 85   [[Timestamp('2009-09-17 00:00:00'), Timestamp(...  21.584797
# 90   [[Timestamp('2009-02-15 00:00:00')], [Timestam...  82.214488
# 92   [[Timestamp('2017-11-03 00:00:00'), Timestamp(...  79.472815
# 93   [[Timestamp('2006-05-18 00:00:00'), Timestamp(...  88.475808
# 95   [[Timestamp('2006-09-28 00:00:00'), Timestamp(...  79.688888
# 100  [[Timestamp('2002-06-20 00:00:00'), Timestamp(...  75.203420
# 101  [[Timestamp('2002-09-09 00:00:00'), Timestamp(...  70.182565
# 102  [[Timestamp('2002-12-12 00:00:00'), Timestamp(...  70.220648
# 103  [[Timestamp('2003-04-10 00:00:00'), Timestamp(...  73.963854
# 105  [[Timestamp('2018-05-03 00:00:00'), Timestamp(...  70.000000
# 135  [[Timestamp('2012-12-11 00:00:00'), Timestamp(...  57.660133
# 139  [[Timestamp('2000-11-20 00:00:00'), Timestamp(...  62.753695
# 146  [[Timestamp('2019-01-01 00:00:00')], [Timestam...  60.000000
# 155  [[Timestamp('2015-05-28 00:00:00'), Timestamp(...  80.012295
# 160  [[Timestamp('2018-03-02 00:00:00')], [Timestam...  70.000000
# 177  [[Timestamp('2014-07-02 00:00:00'), Timestamp(...  60.000000
# 180  [[Timestamp('2019-03-07 00:00:00')], [Timestam...  70.000000
# 190  [[Timestamp('2009-11-19 00:00:00'), Timestamp(...  57.000000
# 196  [[Timestamp('2017-03-03 00:00:00'), Timestamp(...  46.508893
# 206  [[Timestamp('2011-04-01 00:00:00')], [Timestam...  40.000000
# 231  [[Timestamp('2019-10-21 00:00:00')], [Timestam...  80.000000
# 232  [[Timestamp('2016-01-27 00:00:00'), Timestamp(...  50.000000
# 240  [[Timestamp('2009-05-25 00:00:00')], [Timestam...  90.000000
# 243  [[Timestamp('2014-03-05 00:00:00'), Timestamp(...  59.497066
# 244  [[Timestamp('2016-07-19 00:00:00'), Timestamp(...  65.367362
# 245  [[Timestamp('2018-01-25 00:00:00'), Timestamp(...  83.000000
# 255  [[Timestamp('2015-01-30 00:00:00')], [Timestam...  40.000000
# 283  [[Timestamp('1985-08-30 00:00:00'), Timestamp(...  64.730793
# 284  [[Timestamp('2013-08-01 00:00:00'), Timestamp(...  57.000000
# 296  [[Timestamp('2010-04-10 00:00:00'), Timestamp(...  68.000000
# 310               [[Timestamp('2019-03-18 00:00:00')]]  60.000000
# 325  [[Timestamp('2021-10-15 00:00:00')], [Timestam...  49.965103
# 328  [[Timestamp('2021-11-15 00:00:00')], [Timestam...  75.672778
# 357               [[Timestamp('2013-07-03 00:00:00')]]  80.000000
# 381  [[Timestamp('2013-09-10 00:00:00'), Timestamp(...  75.806951
# 424  [[Timestamp('2012-02-22 00:00:00'), Timestamp(...  80.000000
# 431  [[Timestamp('2019-07-25 00:00:00'), Timestamp(...  60.000000
# 433  [[Timestamp('2015-12-11 00:00:00'), Timestamp(...  60.000000
# 450  [[Timestamp('2013-01-15 00:00:00'), Timestamp(...  50.345360
# 496               [[Timestamp('2015-11-30 00:00:00')]]  30.000000
# 512  [[Timestamp('2014-06-03 00:00:00'), Timestamp(...  62.405832
#
#      rating_count  total_rating  total_rating_count  aggregated_rating  \
# 12            0.0     70.000000                 0.0                NaN
# 23            0.0     50.000000                 0.0                NaN
# 25            0.0     63.000000                 0.0                NaN
# 32            8.0     78.101514                12.0          78.250000
# 33            2.0     67.500000                 3.0          65.000000
# 39            0.0     60.000000                 0.0                NaN
# 42            0.0     50.000000                 0.0                NaN
# 45            0.0     50.000000                 0.0                NaN
# 62            0.0     70.000000                 0.0                NaN
# 85            8.0     35.792399                 9.0          50.000000
# 90           10.0     82.214488                10.0                NaN
# 92            9.0     76.736407                16.0          74.000000
# 93           12.0     77.987904                14.0          67.500000
# 95            6.0     67.344444                 9.0          55.000000
# 100          22.0     75.203420                22.0                NaN
# 101          12.0     68.591282                13.0          67.000000
# 102           8.0     70.220648                 8.0                NaN
# 103           9.0     73.963854                 9.0                NaN
# 105           1.0     70.000000                 1.0                NaN
# 135          18.0     51.687209                27.0          45.714286
# 139          21.0     62.753695                21.0                NaN
# 146           2.0     60.000000                 2.0                NaN
# 155           4.0     77.506147                 8.0          75.000000
# 160           3.0     60.000000                 5.0          50.000000
# 177           3.0     60.000000                 3.0                NaN
# 180           3.0     70.000000                 3.0                NaN
# 190           2.0     57.000000                 2.0                NaN
# 196          29.0     50.087780                39.0          53.666667
# 206           3.0     40.000000                 3.0                NaN
# 231           3.0     80.000000                 3.0                NaN
# 232           0.0     50.000000                 0.0                NaN
# 240           0.0     90.000000                 0.0                NaN
# 243           6.0     69.748533                 9.0          80.000000
# 244          29.0     71.350348                38.0          77.333333
# 245           0.0     83.000000                 0.0                NaN
# 255           0.0     40.000000                 0.0                NaN
# 283           5.0     64.730793                 5.0                NaN
# 284           0.0     57.000000                 0.0                NaN
# 296           1.0     68.000000                 1.0                NaN
# 310           0.0     60.000000                 0.0                NaN
# 325           5.0     49.965103                 5.0                NaN
# 328           8.0     75.672778                 8.0                NaN
# 357           0.0     80.000000                 0.0                NaN
# 381          30.0     75.806951                30.0                NaN
# 424           1.0     76.000000                 3.0          72.000000
# 431           1.0     60.000000                 1.0                NaN
# 433           0.0     60.000000                 0.0                NaN
# 450          17.0     65.172680                18.0          80.000000
# 496           0.0     30.000000                 0.0                NaN
# 512           7.0     71.202916                11.0          80.000000
#
#      aggregated_rating_count
# 12                       NaN
# 23                       NaN
# 25                       NaN
# 32                       4.0
# 33                       1.0
# 39                       NaN
# 42                       NaN
# 45                       NaN
# 62                       NaN
# 85                       1.0
# 90                       NaN
# 92                       7.0
# 93                       2.0
# 95                       3.0
# 100                      NaN
# 101                      1.0
# 102                      NaN
# 103                      NaN
# 105                      NaN
# 135                      9.0
# 139                      NaN
# 146                      NaN
# 155                      4.0
# 160                      2.0
# 177                      NaN
# 180                      NaN
# 190                      NaN
# 196                     10.0
# 206                      NaN
# 231                      NaN
# 232                      NaN
# 240                      NaN
# 243                      3.0
# 244                      9.0
# 245                      NaN
# 255                      NaN
# 283                      NaN
# 284                      NaN
# 296                      NaN
# 310                      NaN
# 325                      NaN
# 328                      NaN
# 357                      NaN
# 381                      NaN
# 424                      2.0
# 431                      NaN
# 433                      NaN
# 450                      1.0
# 496                      NaN
# 512                      4.0

# %%
#testing to see if the data was cleaned correctly
BG3_3 = cleaned_df.loc[cleaned_df['name'] == "Baldur's Gate 3"]
BG3_3
# Out:
#                   name      id  category first_release_date  \
# 13628  Baldur's Gate 3  119171         0         2020-10-06
#
#                                                   genres  \
# 13628  ['Role-playing (RPG)', 'Strategy', 'Turn-based...
#
#                                            release_dates     rating  \
# 13628  [[Timestamp('2023-09-06 00:00:00'), Timestamp(...  95.201398
#
#        rating_count  total_rating  total_rating_count  aggregated_rating  \
# 13628         389.0     94.850699               406.0               94.5
#
#        aggregated_rating_count
# 13628                     17.0

# %%
#output the cleaned data to a csv file
cleaned_df.to_csv('../Cleaned Data/video_games_ratings.csv', index=False)
